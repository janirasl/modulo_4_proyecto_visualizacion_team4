# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("files/comida_precios.csv")
df.head()
# Out:
#          Alimento  Tipo  Precio_EUR_kg_L   Sueño  Energia
# 0    Pollo fresco  Real              6.0  Neutro        8
# 1          Salmón  Real             10.0   Bueno        9
# 2          Huevos  Real              3.0   Bueno        8
# 3           Avena  Real              2.0   Bueno        7
# 4  Arroz integral  Real              2.2  Neutro        7

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Alimento         71 non-null     str
#  1   Tipo             71 non-null     str
#  2   Precio_EUR_kg_L  71 non-null     float64
#  3   Sueño            71 non-null     str
#  4   Energia          71 non-null     int64
# dtypes: float64(1), int64(1), str(3)
# memory usage: 2.9 KB

# %% [markdown]
# Hemos detectado que no existen nulos, ni duplicados en el df. El tipo de dato esta correcto

# %%
df.columns
# Out:
# Index(['Alimento', 'Tipo', 'Precio_EUR_kg_L', 'Sueño', 'Energia'], dtype='str')

# %%
df.shape
# Out:
# (71, 5)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Tipo'].value_counts(normalize=True)*100
# Out:
# Tipo
# Real     57.746479
# Ultra    42.253521
# Name: proportion, dtype: float64

# %%
df['Sueño'].value_counts(normalize=True)*100
# Out:
# Sueño
# Malo      42.253521
# Neutro    29.577465
# Bueno     28.169014
# Name: proportion, dtype: float64

# %%
df.drop(columns="Energia", inplace=True)

# %%
df.sample()
# Out:
#         Alimento  Tipo  Precio_EUR_kg_L   Sueño
# 19  Aceite oliva  Real              8.5  Neutro

# %%
df.describe(include=np.number).T
# Out:
#                  count      mean       std  min  25%  50%  75%   max
# Precio_EUR_kg_L   71.0  3.514085  2.677915  0.5  2.0  2.6  4.0  15.0

# %%
df.describe(include=str).T
# Out:
#          count unique           top freq
# Alimento    71     71  Pollo fresco    1
# Tipo        71      2          Real   41
# Sueño       71      3          Malo   30
